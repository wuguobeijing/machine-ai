# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
# %matplotlib inline
from sklearn.datasets._samples_generator import make_blobs
# X为样本特征，Y为样本簇类别， 共1000个样本，每个样本3个特征，共4个簇
X, y = make_blobs(n_samples=10000, n_features=3, centers=[[3,3, 3], [0,0,0], [1,1,1], [2,2,2]], cluster_std=[0.2, 0.1, 0.2, 0.2],
                  random_state =9)
fig = plt.figure()
ax = Axes3D(fig, rect=(0.0, 0.0, 1.0, 1.0), elev=30, azim=20)
plt.scatter(X[:, 0], X[:, 1], X[:, 2],marker='o')
# Out:
# C:\Users\wuguo\AppData\Local\Temp\ipykernel_18132\4200200497.py:11: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig, rect=(0.0, 0.0, 1.0, 1.0), elev=30, azim=20)
# c:\users\wuguo\pycharmprojects\myproject\venv\lib\site-packages\matplotlib\collections.py:982: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
pca = PCA(n_components='mle')
pca.fit(X)
print(pca.explained_variance_ratio_)
print(pca.explained_variance_)
print(pca.n_components_)
# Out:
# Traceback (most recent call last):
#   File "D:\PyCharm\PyCharm 2021.1.1\plugins\python\helpers-pro\jupyter_debug\pydev_jupyter_utils.py", line 69, in attach_to_debugger
#     debugger.prepare_to_run(enable_tracing_from_start=False)
# TypeError: prepare_to_run() got an unexpected keyword argument 'enable_tracing_from_start'
# Failed to connect to target debugger.
# [0.98318212]
# [3.78521638]
# 1

# %%
pca = PCA(n_components=0.99)
pca.fit(X)
print(pca.explained_variance_ratio_)
print(pca.explained_variance_)
print(pca.n_components_)
# Out:
# [0.98318212 0.00850037]
# [3.78521638 0.03272613]
# 2
